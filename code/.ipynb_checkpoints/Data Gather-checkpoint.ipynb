# %%
import pandas as pd
import requests
import json

# %%
url1 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches1.json'
url2 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches2.json'
url3 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches3.json'
url4 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches4.json'
url5 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches5.json'
url6 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches6.json'
url7 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches7.json'
url8 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches8.json'
url9 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches9.json'
url10 = 'https://s3-us-west-1.amazonaws.com/riot-developer-portal/seed-data/matches10.json'
champion_url = 'https://ddragon.leagueoflegends.com/cdn/6.24.1/data/en_US/champion.json'

# %%
# data = requests.get(url1).json()
# data2 = requests.get(url2).json()
# data3 = requests.get(url3).json()
# data4 = requests.get(url4).json()
# data5 = requests.get(url5).json()
# data6 = requests.get(url6).json()
# data7 = requests.get(url7).json()
# data8 = requests.get(url8).json()
# data9 = requests.get(url9).json()
# data10 = requests.get(url10).json()
champion_data = requests.get(champion_url).json()

# %%
for i in range(100):
    data['matches'].append(data2['matches'][i])

for i in range(100):
    data['matches'].append(data3['matches'][i])

for i in range(100):
    data['matches'].append(data4['matches'][i])

for i in range(100):
    data['matches'].append(data5['matches'][i])

for i in range(100):
    data['matches'].append(data6['matches'][i])

for i in range(100):
    data['matches'].append(data7['matches'][i])

for i in range(100):
    data['matches'].append(data8['matches'][i])
    
for i in range(100):
    data['matches'].append(data9['matches'][i])
    
for i in range(100):
    data['matches'].append(data10['matches'][i])

# %%
names = list(champion_data['data'].keys())

champion_list = []
champion_dict = {}

for i in names:
    temp = {}
    temp[champion_data['data'][i]['key']] = i
    champion_list.append(temp)

for i in champion_list:
    champion_dict.update(i)
    
with open("../data/spells.json", "r") as read_file:
    spells = json.load(read_file)

spell_names = {}
for i in spells:
    spell_names.update({i['key']: i['name']})

# %%
player_list = []
for match in range(len(data['matches'])):
    for items in range(5):
        player_dict_item = {}
        player_dict_item['champion'] = data['matches'][match]['participants'][items].get('championId')
        player_dict_item['spell_1'] = data['matches'][match]['participants'][items].get('spell1Id')
        player_dict_item['spell_2'] = data['matches'][match]['participants'][items].get('spell2Id')
        player_dict_item['player_rank'] = data['matches'][match]['participants'][items].get('highestAchievedSeasonTier')
        player_dict_item['victory'] = data['matches'][match]['participants'][items]['stats'].get('win')
        player_dict_item['kills'] = data['matches'][match]['participants'][items]['stats'].get('kills')
        player_dict_item['deaths'] = data['matches'][match]['participants'][items]['stats'].get('deaths')
        player_dict_item['assists'] = data['matches'][match]['participants'][items]['stats'].get('assists')
        player_dict_item['largest_killing_spree'] = data['matches'][match]['participants'][items]['stats'].get('largestKillingSpree')
        player_dict_item['killing_sprees'] = data['matches'][match]['participants'][items]['stats'].get('killingSprees')
        player_dict_item['double_kills'] = data['matches'][match]['participants'][items]['stats'].get('doubleKills')
        player_dict_item['triple_kills'] = data['matches'][match]['participants'][items]['stats'].get('tripleKills')
        player_dict_item['quadra_kills'] = data['matches'][match]['participants'][items]['stats'].get('quadraKills')
        player_dict_item['penta_kills'] = data['matches'][match]['participants'][items]['stats'].get('pentaKills')
        player_dict_item['total_damage_dealt_to_champions'] = data['matches'][match]['participants'][items]['stats'].get('totalDamageDealtToChampions')
        player_dict_item['vision_score'] = data['matches'][match]['participants'][items]['stats'].get('visionScore')
        player_dict_item['total_damage_taken'] = data['matches'][match]['participants'][items]['stats'].get('totalDamageTaken')
        player_dict_item['gold_earned'] = data['matches'][match]['participants'][items]['stats'].get('goldEarned')
        player_dict_item['gold_spent'] = data['matches'][match]['participants'][items]['stats'].get('goldSpent')   
        player_dict_item['turret_kills'] = data['matches'][match]['participants'][items]['stats'].get('turretKills')
        player_dict_item['inhibitor_kills'] = data['matches'][match]['participants'][items]['stats'].get('inhibitorKills')
        player_dict_item['total_minions_killed'] = data['matches'][match]['participants'][items]['stats'].get('totalMinionsKilled')
        player_dict_item['wards_placed'] = data['matches'][match]['participants'][items]['stats'].get('wardsPlaced')
        player_dict_item['wards_killed'] = data['matches'][match]['participants'][items]['stats'].get('wardsKilled')   
        player_dict_item['first_blood_kill'] = data['matches'][match]['participants'][items]['stats'].get('firstBloodKill')
        player_dict_item['first_blood_assist'] = data['matches'][match]['participants'][items]['stats'].get('firstBloodAssist')
        player_dict_item['first_tower_kill'] = data['matches'][match]['participants'][items]['stats'].get('firstTowerKill')
        player_dict_item['first_tower_assist'] = data['matches'][match]['participants'][items]['stats'].get('firstTowerAssist')
        player_dict_item['first_inhibitor_kill'] = data['matches'][match]['participants'][items]['stats'].get('firstInhibitorKill')
        player_dict_item['first_inhibitor_assist'] = data['matches'][match]['participants'][items]['stats'].get('firstInhibitorAssist')  
        player_dict_item['lane'] = data['matches'][match]['participants'][items]['timeline'].get('lane')
        player_dict_item['role'] = data['matches'][match]['participants'][items]['timeline'].get('role')
        
        if data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas'):
            player_dict_item['creep_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('0-10')
            player_dict_item['creep_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('10-20')
            player_dict_item['creep_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('20-30')
            player_dict_item['creep_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('30-end')
            
        if data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas'):
            player_dict_item['gold_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('0-10')
            player_dict_item['gold_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('10-20')  
            player_dict_item['gold_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('20-30')  
            player_dict_item['gold_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('30-end')
    
        
        if data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas'):
            player_dict_item['cs_diff_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('0-10')
            player_dict_item['cs_diff_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('10-20')  
            player_dict_item['cs_diff_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('20-30')  
            player_dict_item['cs_diff_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('30-end')
        
        if data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas'):
            player_dict_item['xp_diff_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('0-10')
            player_dict_item['xp_diff_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('10-20')  
            player_dict_item['xp_diff_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('20-30')  
            player_dict_item['xp_diff_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('30-end')
            
        if data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas'):
            player_dict_item['damage_taken_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('0-10')
            player_dict_item['damage_taken_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('10-20')  
            player_dict_item['damage_taken_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('20-30')  
            player_dict_item['damage_taken_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('30-end')
        
        if data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas'):
            player_dict_item['damage_taken_diff_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('0-10')
            player_dict_item['damage_taken_diff_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('10-20')  
            player_dict_item['damage_taken_diff_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('20-30')  
            player_dict_item['damage_taken_diff_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('30-end')
        
        player_dict_item['team_tower_kills'] = data['matches'][match]['teams'][0]['towerKills']
        player_dict_item['team_baron_kill'] = data['matches'][match]['teams'][0]['baronKills']
        player_dict_item['team_dragon_kills'] = data['matches'][match]['teams'][0]['dragonKills']
        player_dict_item['team_rift_herald_kills'] = data['matches'][match]['teams'][0]['riftHeraldKills']
        player_dict_item['team_first_ban'] = data['matches'][match]['teams'][0]['bans'][0]['championId']
        player_dict_item['team_second_ban'] = data['matches'][match]['teams'][0]['bans'][1]['championId']
        player_dict_item['team_third_ban'] = data['matches'][match]['teams'][0]['bans'][2]['championId']
        player_dict_item['team_fourth_ban'] = data['matches'][match]['teams'][0]['bans'][3]['championId']
        player_dict_item['team_fifth_ban'] = data['matches'][match]['teams'][0]['bans'][4]['championId']      
       
        player_list.append(player_dict_item)
        
    for items in range(5,10):
        player_dict_item = {}
        player_dict_item['champion'] = data['matches'][match]['participants'][items].get('championId')
        player_dict_item['spell_1'] = data['matches'][match]['participants'][items].get('spell1Id')
        player_dict_item['spell_2'] = data['matches'][match]['participants'][items].get('spell2Id')
        player_dict_item['player_rank'] = data['matches'][match]['participants'][items].get('highestAchievedSeasonTier')
        player_dict_item['victory'] = data['matches'][match]['participants'][items]['stats'].get('win')
        player_dict_item['kills'] = data['matches'][match]['participants'][items]['stats'].get('kills')
        player_dict_item['deaths'] = data['matches'][match]['participants'][items]['stats'].get('deaths')
        player_dict_item['assists'] = data['matches'][match]['participants'][items]['stats'].get('assists')
        player_dict_item['largest_killing_spree'] = data['matches'][match]['participants'][items]['stats'].get('largestKillingSpree')
        player_dict_item['killing_sprees'] = data['matches'][match]['participants'][items]['stats'].get('killingSprees')
        player_dict_item['double_kills'] = data['matches'][match]['participants'][items]['stats'].get('doubleKills')
        player_dict_item['triple_kills'] = data['matches'][match]['participants'][items]['stats'].get('tripleKills')
        player_dict_item['quadra_kills'] = data['matches'][match]['participants'][items]['stats'].get('quadraKills')
        player_dict_item['penta_kills'] = data['matches'][match]['participants'][items]['stats'].get('pentaKills')
        player_dict_item['total_damage_dealt_to_champions'] = data['matches'][match]['participants'][items]['stats'].get('totalDamageDealtToChampions')
        player_dict_item['vision_score'] = data['matches'][match]['participants'][items]['stats'].get('visionScore')
        player_dict_item['total_damage_taken'] = data['matches'][match]['participants'][items]['stats'].get('totalDamageTaken')
        player_dict_item['gold_earned'] = data['matches'][match]['participants'][items]['stats'].get('goldEarned')
        player_dict_item['gold_spent'] = data['matches'][match]['participants'][items]['stats'].get('goldSpent')   
        player_dict_item['turret_kills'] = data['matches'][match]['participants'][items]['stats'].get('turretKills')
        player_dict_item['inhibitor_kills'] = data['matches'][match]['participants'][items]['stats'].get('inhibitorKills')
        player_dict_item['total_minions_killed'] = data['matches'][match]['participants'][items]['stats'].get('totalMinionsKilled')
        player_dict_item['wards_placed'] = data['matches'][match]['participants'][items]['stats'].get('wardsPlaced')
        player_dict_item['wards_killed'] = data['matches'][match]['participants'][items]['stats'].get('wardsKilled')   
        player_dict_item['first_blood_kill'] = data['matches'][match]['participants'][items]['stats'].get('firstBloodKill')
        player_dict_item['first_blood_assist'] = data['matches'][match]['participants'][items]['stats'].get('firstBloodAssist')
        player_dict_item['first_tower_kill'] = data['matches'][match]['participants'][items]['stats'].get('firstTowerKill')
        player_dict_item['first_tower_assist'] = data['matches'][match]['participants'][items]['stats'].get('firstTowerAssist')
        player_dict_item['first_inhibitor_kill'] = data['matches'][match]['participants'][items]['stats'].get('firstInhibitorKill')
        player_dict_item['first_inhibitor_assist'] = data['matches'][match]['participants'][items]['stats'].get('firstInhibitorAssist')  
        player_dict_item['lane'] = data['matches'][match]['participants'][items]['timeline'].get('lane')
        player_dict_item['role'] = data['matches'][match]['participants'][items]['timeline'].get('role')
        
        if data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas'):
            player_dict_item['creep_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('0-10')
            player_dict_item['creep_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('10-20')
            player_dict_item['creep_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('20-30')
            player_dict_item['creep_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('creepsPerMinDeltas').get('30-end')
            
        if data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas'):
            player_dict_item['gold_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('0-10')
            player_dict_item['gold_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('10-20')  
            player_dict_item['gold_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('20-30')  
            player_dict_item['gold_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('goldPerMinDeltas').get('30-end')
    
        
        if data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas'):
            player_dict_item['cs_diff_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('0-10')
            player_dict_item['cs_diff_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('10-20')  
            player_dict_item['cs_diff_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('20-30')  
            player_dict_item['cs_diff_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('csDiffPerMinDeltas').get('30-end')
        
        if data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas'):
            player_dict_item['xp_diff_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('0-10')
            player_dict_item['xp_diff_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('10-20')  
            player_dict_item['xp_diff_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('20-30')  
            player_dict_item['xp_diff_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('xpDiffPerMinDeltas').get('30-end')
            
        if data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas'):
            player_dict_item['damage_taken_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('0-10')
            player_dict_item['damage_taken_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('10-20')  
            player_dict_item['damage_taken_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('20-30')  
            player_dict_item['damage_taken_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenPerMinDeltas').get('30-end')
        
        if data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas'):
            player_dict_item['damage_taken_diff_per_min_delta_0_10'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('0-10')
            player_dict_item['damage_taken_diff_per_min_delta_10_20'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('10-20')  
            player_dict_item['damage_taken_diff_per_min_delta_20_30'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('20-30')  
            player_dict_item['damage_taken_diff_per_min_delta_30_end'] = data['matches'][match]['participants'][items]['timeline'].get('damageTakenDiffPerMinDeltas').get('30-end')
        
        player_dict_item['team_tower_kills'] = data['matches'][match]['teams'][1]['towerKills']
        player_dict_item['team_baron_kill'] = data['matches'][match]['teams'][1]['baronKills']
        player_dict_item['team_dragon_kills'] = data['matches'][match]['teams'][1]['dragonKills']
        player_dict_item['team_rift_herald_kills'] = data['matches'][match]['teams'][1]['riftHeraldKills']
        player_dict_item['team_first_ban'] = data['matches'][match]['teams'][1]['bans'][0]['championId']
        player_dict_item['team_second_ban'] = data['matches'][match]['teams'][1]['bans'][1]['championId']
        player_dict_item['team_third_ban'] = data['matches'][match]['teams'][1]['bans'][2]['championId']
        player_dict_item['team_fourth_ban'] = data['matches'][match]['teams'][1]['bans'][3]['championId']
        player_dict_item['team_fifth_ban'] = data['matches'][match]['teams'][1]['bans'][4]['championId']
        
        player_list.append(player_dict_item)

# %%
pd.DataFrame(player_list).shape
# Out:
# (10000, 65)

# %%
players = pd.DataFrame(player_list)

# %%
players.head()
# Out:
#    champion  spell_1  spell_2 player_rank  victory  kills  deaths  assists  \
# 0       240        4       12    UNRANKED     True     17       5       25
# 1        29        4        7        GOLD     True     24      14       15
# 2        63        4        3      SILVER     True      8      17       22
# 3        64        4       11        GOLD     True      7       7       29
# 4         1        4       14      SILVER     True     10      10       20
#
#    largest_killing_spree  killing_sprees  ...  \
# 0                      8               3  ...
# 1                      8               5  ...
# 2                      2               2  ...
# 3                      2               3  ...
# 4                      3               3  ...
#
#    damage_taken_diff_per_min_delta_30_end  team_tower_kills  team_baron_kill  \
# 0                                  568.56                 9                0
# 1                                   54.60                 9                0
# ...

# %%
players['champion'] = players['champion'].astype(str)
players['team_first_ban'] = players['team_first_ban'].astype(str)
players['team_second_ban'] = players['team_second_ban'].astype(str)
players['team_third_ban'] = players['team_third_ban'].astype(str)
players['team_fourth_ban'] = players['team_fourth_ban'].astype(str)
players['team_fifth_ban'] = players['team_fifth_ban'].astype(str)
players['spell_1'] = players['spell_1'].astype(str)
players['spell_2'] = players['spell_2'].astype(str)

# %%
players['champion'] = players['champion'].map(champion_dict)
players['team_first_ban'] = players['team_first_ban'].map(champion_dict)
players['team_second_ban'] = players['team_second_ban'].map(champion_dict)
players['team_third_ban'] = players['team_third_ban'].map(champion_dict)
players['team_fourth_ban'] = players['team_fourth_ban'].map(champion_dict)
players['team_fifth_ban'] = players['team_fifth_ban'].map(champion_dict)
players['spell_1'] = players['spell_1'].map(spell_names)
players['spell_2'] = players['spell_2'].map(spell_names)

# %%
players.head()
# Out:
#   champion spell_1   spell_2 player_rank  victory  kills  deaths  assists  \
# 0     Kled   Flash  Teleport    UNRANKED     True     17       5       25
# 1   Twitch   Flash      Heal        GOLD     True     24      14       15
# 2    Brand   Flash   Exhaust      SILVER     True      8      17       22
# 3   LeeSin   Flash     Smite        GOLD     True      7       7       29
# 4    Annie   Flash    Ignite      SILVER     True     10      10       20
#
#    largest_killing_spree  killing_sprees  ...  \
# 0                      8               3  ...
# 1                      8               5  ...
# 2                      2               2  ...
# 3                      2               3  ...
# 4                      3               3  ...
#
#    damage_taken_diff_per_min_delta_30_end  team_tower_kills  team_baron_kill  \
# 0                                  568.56                 9                0
# 1                                   54.60                 9                0
# ...

# %%
players.to_csv('../data/players.csv')
